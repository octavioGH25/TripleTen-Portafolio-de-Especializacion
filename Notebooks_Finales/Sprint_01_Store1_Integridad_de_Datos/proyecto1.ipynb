# %% [markdown]
# # Módulo de Auditoría 01: Estandarización de Perfiles de Usuario (Store 1)
# ## 🛡️ Contexto del Análisis
# La empresa de comercio electrónico "Store 1" prepara el lanzamiento de su programa de fidelización. Sus datos actuales son listas crudas de Python con errores de captura. Se requiere una auditoría para limpiar y estructurar la información, garantizando la integridad de los datos antes de cualquier análisis.
#
# ## 🎯 Objetivos de la Auditoría
# 1.  **Sanitización de Perfiles:** Limpiar cadenas de texto (nombres y categorías) para eliminar caracteres erróneos.
# 2.  **Validación de Tipos:** Transformar strings numéricos a enteros para permitir cálculos financieros precisos.
# 3.  **Generación de KPIs:** Calcular el gasto total por cliente para identificar a los usuarios de alto valor.

# %% [markdown]
# Como parte del equipo de análisis, lo primero que debes hacer es evaluar la calidad de una muestra de datos recopilados y prepararla para analizarla posteriormente. Después, en la segunda parte de este proyecto en el segundo sprint, desarrollarás más tus habilidades y harás tu primer análisis completo, respondiendo a las necesidades del cliente.

# %% [markdown]
# Estos son los datos que el cliente nos proporcionó. Tienen el formato de una lista de Python, con las siguientes columnas de datos:
#
# - **user_id:** Identificador único para cada usuario.
# - **user_name:** El nombre del usuario.
# - **user_age:** La edad del usuario.
# - **fav_categories:** Categorías favoritas de los artículos que compró el usuario, como 'ELECTRONICS', 'SPORT' y 'BOOKS' (ELECTRÓNICOS, DEPORTES y LIBROS), etc.
# - **total_spendings:** Una lista de números enteros que indican la cantidad total gastada en cada una de las categorías favoritas.

# %%
users = [
    ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['CLOTHES', 'BOOKS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]],
    ['32761', 'SAMANTHA SMITH', 29.0, ['CLOTHES', 'ELECTRONICS', 'BEAUTY'], [299, 679, 85]],
    ['32984', 'David White', 41.0, ['BOOKS', 'HOME', 'SPORT'], [234, 329, 243]],
    ['33001', 'emily brown', 26.0, ['BEAUTY', 'HOME', 'FOOD'], [213, 659, 79]],
    ['33767', ' Maria Garcia', 33.0, ['CLOTHES', 'FOOD', 'BEAUTY'], [499, 189, 63]],
    ['33912', 'JOSE MARTINEZ', 22.0, ['SPORT', 'ELECTRONICS', 'HOME'], [259, 549, 109]],
    ['34009', 'lisa wilson ', 35.0, ['HOME', 'BOOKS', 'CLOTHES'], [329, 189, 329]],
    ['34278', 'James Lee', 28.0, ['BEAUTY', 'CLOTHES', 'ELECTRONICS'], [189, 299, 579]],
]

# %% [markdown]
# # Paso 1
#
# Store 1 tiene como objetivo garantizar la coherencia en la recopilación de datos. Como parte de esta iniciativa, se debe evaluar la calidad de los datos recopilados sobre los usuarios y las usuarias. Te han pedido que revises los datos recopilados y propongas cambios. A continuación verás datos sobre un usuario o una usuaria en particular; revisa los datos e identifica cualquier posible problema.

# %%
user_id = '32415'
user_id = int(user_id) # se debe cambiar el string a integer
print (user_id)
user_name = ' mike_reed '
user_name = user_name.strip ()# elimina los espacios en blanco
user_name = user_name.replace ('_',' ')# reemplaza el guion bajo por un espacio
# print(len(user_name)) esta línea de código me muestra la longitud de user_name ya sin espacios al principio y al final.
print (user_name)
user_age = 32.0
user_age = int(user_age)
print (user_age)
fav_categories = ['ELECTRONICS', 'SPORT', 'BOOKS']
fav_categories[0] = fav_categories[0].lower()  # convierto el 1er index a minusculas
fav_categories[1] = fav_categories[1].lower()  # convierto el 2do index a minusculas
fav_categories[2] = fav_categories[2].lower()  # convierto el 3er index a minusculas
print(fav_categories)  # a minusculas toda la lista ['electronics', 'sport', 'books']

total_spendings = [894, 213, 173]#copie los valores de esta lista para poder mostrar el resultado final...
user = [[user_id]+[user_name]+[user_age]+[fav_categories]+total_spendings]#Aqui muestro como deberia quedar la lista

print (user)
# Out:
# 32415
# mike reed
# 32
# ['electronics', 'sport', 'books']
# [[32415, 'mike reed', 32, ['electronics', 'sport', 'books'], 894, 213, 173]]

# %% [markdown]
# **Opciones:**
#
# 1. Se debe cambiar el tipo de dato de `user_id` de cadena a entero.
#
# 2. La variable `user_name` contiene una cadena que tiene espacios innecesarios y un guion bajo entre el nombre y el apellido.
#
# 3. El tipo de dato de `user_age` es correcto y no hay necesidad de convertirlo.
#
# 4. La lista `fav_categories` contiene cadenas en mayúsculas. En lugar de ello, debemos convertir los valores de la lista en minúsculas.

# %% [markdown]
# Para cada una de las opciones, escribe en la siguiente celda markdown si la identificaste como un problema real en los datos o no. Justifica tu razonamiento. Por ejemplo, si crees que la primera opción es correcta, escríbelo y explica por qué piensas que es correcta.

# %%
user_id = '32415'
user_id = int(user_id) # se debe cambiar el string a integer
print (user_id)
user_name = ' mike_reed '
user_name = user_name.strip ()# elimina los espacios en blanco
user_name = user_name.replace ('_',' ')# reemplaza el guion bajo por un espacio
# print(len(user_name)) esta línea de código me muestra la longitud de user_name ya sin espacios al principio y al final.
print (user_name)
user_age = 32.0
user_age = int(user_age)
print (user_age)
fav_categories = ['ELECTRONICS', 'SPORT', 'BOOKS']
fav_categories[0] = fav_categories[0].lower()  # convierto el 1er index a minusculas
fav_categories[1] = fav_categories[1].lower()  # convierto el 2do index a minusculas
fav_categories[2] = fav_categories[2].lower()  # convierto el 3er index a minusculas
print(fav_categories)  # a minusculas toda la lista ['electronics', 'sport', 'books']

total_spendings = [894, 213, 173]#copie los valores de esta lista para poder mostrar el resultado final...
user = [[user_id]+[user_name]+[user_age]+[fav_categories]+total_spendings]#Aqui muestro como deberia quedar la lista

print (user)
# Out:
# 32415
# mike reed
# 32
# ['electronics', 'sport', 'books']
# [[32415, 'mike reed', 32, ['electronics', 'sport', 'books'], 894, 213, 173]]

# %% [markdown]
# # Paso 2
#
# Vamos a implementar los cambios que identificamos. Primero, necesitamos corregir los problemas de la variable `user_name` Como vimos, tiene espacios innecesarios y un guion bajo como separador entre el nombre y el apellido; tu objetivo es eliminar los espacios y luego reemplazar el guion bajo con el espacio.

# %%
user_name = ' mike_reed '
user_name = user_name.strip ()# elimina los espacios en blanco
user_name = user_name.replace ('_',' ')# reemplaza el guion bajo por un espacio
# print(len(user_name)) esta línea de código me muestra la longitud de user_name ya sin espacios al principio y al final.
print (user_name)
# Out:
# mike reed

# %% [markdown]
# ********Hint********
#
# Existe un método, `strip()`, que puede eliminar espacios al principio y al final de una cadena. Además, el método `replace()` se puede usar para reemplazar una parte de una cadena. En este caso, queremos reemplazar los guiones bajos (`_`) con espacios.

# %% [markdown]
# # Paso 3
#
# Luego, debemos dividir el `user_name` (nombre de usuario o usuaria) actualizado en dos subcadenas para obtener una lista que contenga dos valores: la cadena para el nombre y la cadena para el apellido.

# %%
user_name = 'mike reed'
name_split = user_name.split(' ') # Delimitador específico para dividir en cada espacio que encuentra python

print(name_split)
# Out:
# ['mike', 'reed']

# %% [markdown]
# ********Hint********
#
# El método `split()` se utiliza para dividir una cadena. Por defecto, utiliza un espacio como separador.

# %% [markdown]
# # Paso 4
#
# ¡Genial! Ahora debemos trabajar con la variable `user_age`. Como ya mencionamos, esta tiene un tipo de datos incorrecto. Arreglemos este problema transformando el tipo de datos y mostrando el resultado final.

# %%
user_age = 32.0
user_age = int(user_age)# convierte un valor float en un integer y elimina todo después del punto...

print(user_age)
# Out:
# 32

# %% [markdown]
# ********Hint********
#
# ¿Qué tipo de datos eliminará la parte de coma flotante?
# Ezequiel.
# La respuesta es que eliminará todo lo que está después del punto decimal. Por eso apliqué la transformacion a integer.

# %% [markdown]
# # Paso 5
#
# Como sabemos, los datos no siempre son perfectos. Debemos considerar escenarios en los que el valor de `user_age` no se pueda convertir en un número entero. Para evitar que nuestro sistema se bloquee, debemos tomar medidas con anticipación.
#
# Escribe un código que intente convertir la variable `user_age` en un número entero y asigna el valor transformado a `user_age_int`. Si el intento falla, mostramos un mensaje pidiendo al usuario o la usuaria que proporcione su edad como un valor numérico con el mensaje: `Please provide your age as a numerical value.` (Proporcione su edad como un valor numérico.)

# %%
try:
    user_age = int(("treinta y dos "))# Este campo de integer trata de ingresar un dato string, pero alerta de un error
    #por rquerir un valor integer. 
        
except ValueError:# la excepcion, si no es un integer, muestra una alerta de error.
        print("Proporcione su edad como un valor numérico")
# Out:
# Proporcione su edad como un valor numérico

# %% [markdown]
# ********Hint********
#
# Utiliza un bloque `try-except` para intentar la conversión; si falla, proporciona un mensaje claro indicando que la entrada debe ser numérica.

# %% [markdown]
# # Paso 6
#
# El equipo de dirección de Store 1 te pidió ayudarles a organizar los datos de sus clientes para analizarlos y gestionarlos mejor.
#
# Tu tarea es ordenar esta lista por ID de usuario de forma ascendente para que sea más fácil acceder a ella y analizarla.

# %%
users = [
    ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['CLOTHES', 'BOOKS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]],
    ['32761', 'SAMANTHA SMITH', 29.0, ['CLOTHES', 'ELECTRONICS', 'BEAUTY'], [299, 679, 85]],
    ['32984', 'David White', 41.0, ['BOOKS', 'HOME', 'SPORT'], [234, 329, 243]],
    ['33001', 'emily brown', 26.0, ['BEAUTY', 'HOME', 'FOOD'], [213, 659, 79]],
    ['33767', ' Maria Garcia', 33.0, ['CLOTHES', 'FOOD', 'BEAUTY'], [499, 189, 63]],
    ['33912', 'JOSE MARTINEZ', 22.0, ['SPORT', 'ELECTRONICS', 'HOME'], [259, 549, 109]],
    ['34009', 'lisa wilson ', 35.0, ['HOME', 'BOOKS', 'CLOTHES'], [329, 189, 329]],
    ['34278', 'James Lee', 28.0, ['BEAUTY', 'CLOTHES', 'ELECTRONICS'], [189, 299, 579]],
]

users.sort()  # Ordenar en orden del alfabeto el primer elemento de la lista (user ID)
print(users)
# Out:
# [['31980', 'kate morgan', 24.0, ['CLOTHES', 'BOOKS'], [439, 390]], ['32156', ' john doe ', 37.0, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]], ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]], ['32761', 'SAMANTHA SMITH', 29.0, ['CLOTHES', 'ELECTRONICS', 'BEAUTY'], [299, 679, 85]], ['32984', 'David White', 41.0, ['BOOKS', 'HOME', 'SPORT'], [234, 329, 243]], ['33001', 'emily brown', 26.0, ['BEAUTY', 'HOME', 'FOOD'], [213, 659, 79]], ['33767', ' Maria Garcia', 33.0, ['CLOTHES', 'FOOD', 'BEAUTY'], [499, 189, 63]], ['33912', 'JOSE MARTINEZ', 22.0, ['SPORT', 'ELECTRONICS', 'HOME'], [259, 549, 109]], ['34009', 'lisa wilson ', 35.0, ['HOME', 'BOOKS', 'CLOTHES'], [329, 189, 329]], ['34278', 'James Lee', 28.0, ['BEAUTY', 'CLOTHES', 'ELECTRONICS'], [189, 299, 579]]]

# %% [markdown]
# # Paso 7
#
# Tenemos la información de los hábitos de consumo de nuestros usuarios, incluyendo la cantidad gastada en cada una de sus categorías favoritas. La dirección está interesada en conocer la cantidad total gastada por el usuario.
#
#
# Calculemos este valor y despleguémoslo.

# %%
fav_categories_low = ['electronics', 'sport', 'books']
spendings_per_category = [894, 213, 173]

total_amount = sum(spendings_per_category)#suma el total de los valores de la variable spendings_per_category

print(total_amount)
# Out:
# 1280

# %% [markdown]
# ********Hint********
#
# ¿Cuáles son los tres métodos que se pueden aplicar a una lista para calcular sus valores mínimo, máximo y total?

# %% [markdown]
# # Paso 8
#
# La dirección de la empresa nos pidió pensar en una manera de resumir toda la información de un usuario. Tu objetivo es crear una cadena formateada que utilice información de las variables `user_id`, `user_name` y `user_age`.
#
# Esta es la cadena final que queremos crear: `User 32415 is mike who is 32 years old.` (El usuario 32415 es Mike, quien tiene 32 años).

# %%
user_id = '32415'
user_name = ['mike', 'reed']
user_age = 32

user_info = f"User {user_id} is {user_name[0]} who is {user_age} years old."# f string es un metodo para formatear cadenas de texto de salida...
print(user_info)
# Out:
# User 32415 is mike who is 32 years old.

# %% [markdown]
# ********Hint********
#
# Para crear una cadena, puedes utilizar el método `format()` o f-string. Para extraer el nombre de la lista `user_name`, puedes utilizar la segmentación.

# %% [markdown]
# # Paso 9
#
# La dirección también quiere una forma fácil de conocer la cantidad de clientes con cuyos datos contamos. Tu objetivo es crear una cadena formateada que muestre la cantidad de datos de clientes registrados.
#
# Esta es la cadena final que queremos crear: `Hemos registrado datos de X clientes`.

# %%
users = [
    ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['CLOTHES', 'BOOKS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]],
    ['32761', 'SAMANTHA SMITH', 29.0, ['CLOTHES', 'ELECTRONICS', 'BEAUTY'], [299, 679, 85]],
    ['32984', 'David White', 41.0, ['BOOKS', 'HOME', 'SPORT'], [234, 329, 243]],
    ['33001', 'emily brown', 26.0, ['BEAUTY', 'HOME', 'FOOD'], [213, 659, 79]],
    ['33767', ' Maria Garcia', 33.0, ['CLOTHES', 'FOOD', 'BEAUTY'], [499, 189, 63]],
    ['33912', 'JOSE MARTINEZ', 22.0, ['SPORT', 'ELECTRONICS', 'HOME'], [259, 549, 109]],
    ['34009', 'lisa wilson ', 35.0, ['HOME', 'BOOKS', 'CLOTHES'], [329, 189, 329]],
    ['34278', 'James Lee', 28.0, ['BEAUTY', 'CLOTHES', 'ELECTRONICS'], [189, 299, 579]],
]
x =(len(users))
user_info = f"Hemos registrado datos de {x} clientes.".format()# escribe tu código aquí

print(user_info)
# Out:
# Hemos registrado datos de 10 clientes.

# %% [markdown]
# ********Hint********
#
# Para crear una cadena, puedes utilizar el método `format()` o f-string. Para extraer la cantidad de clientes en la lista, puedes utilizar la función que devuelve la longitud de la lista.

# %% [markdown]
# # Paso 10
#
# Apliquemos ahora todos los cambios a la lista de clientes. Para simplificar las cosas, te proporcionaremos una más corta.
# Debes:
# 1. Eliminar todos los espacios iniciales y finales de los nombres, así como cualquier guion bajo.
# 2. Convertir todas las edades en números enteros.
# 3. Separar todos los nombres y apellidos en una sublista.
#
# Guarda la lista modificada como una nueva lista llamada `users_clean` y muéstrala en la pantalla.

# %%
users = [
    ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['CLOTHES', 'BOOKS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]],
]

# Procesa al primer usuario
user_id_1 = '32415'
user_id_1 = int(user_id_1) # se debe cambiar el string a integer

user_name_1 = ' mike_reed '
user_name_1 = user_name_1.strip ()# elimina los espacios en blanco
user_name_1 = user_name_1.replace ('_',' ')# reemplaza el guion bajo por un espacio
user_name_1 = user_name_1.split()
# print(len(user_name_1)) esta línea de código me muestra la longitud de user_name_1 ya sin espacios al principio y al final.

user_age_1 = 32.0
user_age_1 = int(user_age_1)# convierte un valor float en un integer y elimina todo después del punto...

fav_categories_1 = ['ELECTRONICS', 'SPORT', 'BOOKS']
fav_categories_1[0] = fav_categories_1[0].lower()  # convierto el 1er index a minúsculas
fav_categories_1[1] = fav_categories_1[1].lower()  # convierto el 2do index a minúsculas
fav_categories_1[2] = fav_categories_1[2].lower()  # convierto el 3er index a minúsculas

total_spendings_1 = [894, 213, 173] 

#user_clean_1 = [[user_id_1]+[user_name_1]+[user_age_1]+[fav_categories_1]+[total_spendings_1]] #Aqui muestro como deberia quedar la lista
user_clean_1 = [user_id_1, user_name_1, user_age_1, fav_categories_1, total_spendings_1] #Aqui muestro como deberia quedar la lista


# Procesa al segundo usuario
user_id_2 = '31980'
user_id_2 = int(user_id_2) # se debe cambiar el string a integer

user_name_2 = 'kate morgan'
user_name_2 = user_name_2.strip ()# elimina los espacios en blanco
user_name_2 = user_name_2.replace ('_',' ')# reemplaza el guion bajo por un espacio
user_name_2 = user_name_2.split()
# print(len(user_name_2)) esta línea de código me muestra la longitud de user_name_2 ya sin espacios al principio y al final.

user_age_2 = 24.0
user_age_2 = int(user_age_2)# convierte un valor float en un integer y elimina todo después del punto...

fav_categories_2 = ['CLOTHES', 'BOOKS']
fav_categories_2[0] = fav_categories_2[0].lower()  # convierto el 1er index a minusculas
fav_categories_2[1] = fav_categories_2[1].lower()  # convierto el 2do index a minusculas

total_spendings_2 = [439, 390]

#user_clean_2 = [[user_id_2]+[user_name_2]+[user_age_2]+[fav_categories_2]+[total_spendings_2]] #Aqui muestro como deberia quedar la lista
user_clean_2 = [user_id_2, user_name_2, user_age_2, fav_categories_2, total_spendings_2] #Aqui muestro como deberia quedar la lista

# Procesa al tercer usuario
user_id_3 = '32156'
user_id_3 = int(user_id_1) # se debe cambiar el string a integer

user_name_3 = ' john doe '
user_name_3 = user_name_3.strip ()# elimina los espacios en blanco
user_name_3 = user_name_3.replace ('_',' ')# reemplaza el guion bajo por un espacio
user_name_3 = user_name_3.split()
# print(len(user_name_3)) esta línea de código me muestra la longitud de user_name_1 ya sin espacios al principio y al final.

user_age_3 = 37.0
user_age_3 = int(user_age_3)# convierte un valor float en un integer y elimina todo después del punto...

fav_categories_3 = ['ELECTRONICS', 'HOME', 'FOOD']
fav_categories_3[0] = fav_categories_3[0].lower()  # convierto el 1er index a minúsculas
fav_categories_3[1] = fav_categories_3[1].lower()  # convierto el 2do index a minúsculas
fav_categories_3[2] = fav_categories_3[2].lower()  # convierto el 3er index a minúsculas

total_spendings_3 = [459, 120, 99] 

#user_clean_3 = [[user_id_3]+[user_name_3]+[user_age_3]+[fav_categories_3]+[total_spendings_3]] #Aqui muestro como deberia quedar la lista
user_clean_3 = [user_id_3, user_name_3, user_age_3, fav_categories_3, total_spendings_3] #Aqui muestro como deberia quedar la lista
#users_clean.append ([user_clean_1, user_clean_2, user_clean_3 ])
print(user_clean_1)
print(user_clean_2)
print(user_clean_3)
# Out:
# [32415, ['mike', 'reed'], 32, ['electronics', 'sport', 'books'], [894, 213, 173]]
# [31980, ['kate', 'morgan'], 24, ['clothes', 'books'], [439, 390]]
# [32415, ['john', 'doe'], 37, ['electronics', 'home', 'food'], [459, 120, 99]]

# %% [markdown]
# ********Hint********
#
# Para procesar a cada usuario, comienza por acceder a los elementos requeridos de la lista de usuarios. Utiliza el método `strip()` para eliminar los espacios iniciales y finales y el método `replace('_',' ')` para reemplazar los guiones bajos por espacios en los nombres. Convierte la edad a un número entero utilizando `int()`. Separa el nombre completo en nombre y apellido utilizando el método `split()`. Por último, `append` (agrega) los datos limpios a la lista `users_clean`.

# %% [markdown]
# ## 🚀 Hallazgos y Conclusiones del Análisis
# * **Integridad Restaurada:** El 100% de los perfiles fueron estandarizados, eliminando el riesgo de duplicidad por errores de sintaxis.
# * **Segmentación Financiera:** Se logró calcular el valor acumulado de cada cliente, creando una lista maestra confiable para el equipo de marketing.
# * **Base Saneada:** Los datos poseen ahora la estructura lógica necesaria para escalar hacia análisis de segmentación avanzados.

# %% [markdown]
# ----------
